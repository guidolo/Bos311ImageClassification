# %%
import sys
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from skimage import img_as_float
from skimage import color

sys.path.insert(0, '/home/guido/NEU/DA 5030 Introduction to Data MiningMachine Learning/FinalProject/Laboratory/ImageProcessing/')
import ImageProcessing as im

# %%
import glob # for bulk file import
import os

os.getcwd()
os.chdir("/home/guido/NEU")

# %%
# %matplotlib inline
# Set defaults
plt.rcParams['image.cmap'] = 'gray' # Display grayscale images in... graysc
plt.rcParams['image.interpolation'] = 'none' # Use nearest-neighbour
plt.rcParams['figure.figsize'] = 10, 10

# %%
imgpathsTrash = glob.glob("./DA 5030 Introduction to Data MiningMachine Learning/FinalProject/311pictures/Trash/*.jpg")

# %%
imgpathsGrafiti = glob.glob("./DA 5030 Introduction to Data MiningMachine Learning/FinalProject/311pictures/Grafiti/*.jpg")

# %%
x=imgpathsGrafiti[10]
img = mpimg.imread(x)
plt.imshow(img)

# %%
img_sk = im.downsample_image(img,10)

plt.imshow(img_sk)

# %%
img_red = im.plot_rgb_components(img, "red")
plt.imshow(img_red)

# %%
img_red = im.plot_rgb_components(img, "blue")
plt.imshow(img_red)

# %%
img_red = im.plot_rgb_components(img, "green")
plt.imshow(img_red)

# %%
img_ve = im.find_vertical_edges(img)
plt.imshow(img_ve)

# %%
img_he = im.find_horizontal_edges(img)
plt.imshow(img_he)

# %%
imgbw = img_as_float(color.rgb2grey(img))
img_ca = im.canny_image(imgbw)
plt.imshow(img_ca)

# %%
img_ls = im.slic_image(img)
plt.imshow(img_ls)
